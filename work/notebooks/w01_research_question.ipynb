# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Utsabsinha19/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane: Refresh / Content Opportunity Scoring
#
# I want to identify which pages should be reviewed first when deciding where content improvement effort is most useful. I chose this lane because the Week 1 and Week 2 experiments showed that search performance contains measurable signals that can help prioritize pages. A ranked review list would be more useful to an editor than looking at thousands of pages individually.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Lane: Refresh / Content Opportunity Scoring")
print("Goal: prioritize pages for content review.")
# Out:
# Lane: Refresh / Content Opportunity Scoring
# Goal: prioritize pages for content review.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
#
# The decision is which pages an editor or SEO/content team member should review first. The output should help prioritize pages that show signs of content opportunity or declining performance. A wrong recommendation could waste an editor's time on a page that does not need attention, while a missed opportunity could leave a genuinely weak page unreviewed. Data and ML may help because several signals such as position, impressions, clicks, CTR, content characteristics, and historical performance can interact in ways that are difficult to capture with one simple rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Decision: Which pages should be reviewed first?")
print("Actor: Editor or SEO/content team")
print("Main risk: Wasting review time or missing a useful content opportunity.")
# Out:
# Decision: Which pages should be reviewed first?
# Actor: Editor or SEO/content team
# Main risk: Wasting review time or missing a useful content opportunity.

# %%
import os

print("Current folder:", os.getcwd())
print("Files here:")
print(os.listdir())
# Out:
# Current folder: /content
# Files here:
# ['.config', 'sample_data']

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/flyrank-bih/flyrank-ml-internship-starter/main/data/raw/content_refresh_anonymized.csv"

df = pd.read_csv(url)

print("Number of rows:", len(df))
print("Number of columns:", len(df.columns))
print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# Number of rows: 30000
# Number of columns: 44
# Average CTR: 0.5107

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work will provide observed and measured patterns in the available data and can support directional recommendations about which pages may deserve review first. The results can be used as decision-support rather than as proof of why a page changed. This work will not claim causal effects and will not claim to predict Google's ranking algorithm. Any recommendations will be limited to the signals and time windows available in the dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
print("Claims will be limited to observed and measured patterns.")
print("Results will be treated as directional decision-support.")
print("No causal claims or claims about predicting Google's ranking algorithm.")
# Out:
# Claims will be limited to observed and measured patterns.
# Results will be treated as directional decision-support.
# No causal claims or claims about predicting Google's ranking algorithm.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
